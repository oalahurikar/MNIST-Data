# %%
from tensorflow.examples.tutorials.mnist import input_data
import tensorflow as tf
import numpy as np
import math
#from helper import batches  # Helper function created in Mini-batching section

# %%
def print_epoch_stats(epoch_i, sess, last_features, last_labels):
    """
    Print cost and validation accuracy of an epoch
    """
    current_cost = sess.run(
        cost,
        feed_dict={features: last_features, labels: last_labels})
    valid_accuracy = sess.run(
        accuracy,
        feed_dict={features: valid_features, labels: valid_labels})
    print('Epoch: {:<4} - Cost: {:<8.3} Valid Accuracy: {:<5.3}'.format(
        epoch_i,
        current_cost,
        valid_accuracy))

# %%
n_input = 784  # MNIST data input (img shape: 28*28)
n_classes = 10  # MNIST total classes (0-9 digits)

# Import MNIST data
mnist = input_data.read_data_sets('/datasets/ud730/mnist', one_hot=True)

# The features are already scaled and the data is shuffled
train_features = mnist.train.images
valid_features = mnist.validation.images
test_features = mnist.test.images

train_labels = mnist.train.labels.astype(np.float32)
valid_labels = mnist.validation.labels.astype(np.float32)
test_labels = mnist.test.labels.astype(np.float32)

# Features and Labels
features = tf.placeholder(tf.float32, [None, n_input])
labels = tf.placeholder(tf.float32, [None, n_classes])

# Weights & bias
weights = tf.Variable(tf.random_normal([n_input, n_classes]))
bias = tf.Variable(tf.random_normal([n_classes]))

# Logits - xW + b
logits = tf.add(tf.matmul(features, weights), bias)

# Define loss and optimizer
learning_rate = tf.placeholder(tf.float32)
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits, labels))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate).minimize(cost)
# Out:
# Extracting /datasets/ud730/mnist\train-images-idx3-ubyte.gz
# Extracting /datasets/ud730/mnist\train-labels-idx1-ubyte.gz
# Extracting /datasets/ud730/mnist\t10k-images-idx3-ubyte.gz
# Extracting /datasets/ud730/mnist\t10k-labels-idx1-ubyte.gz

# %%
# Calculate accuracy
correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(labels, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))


def batches(batch_size, features, labels):
    """
    Create batches of features and labels
    :param batch_size: The batch size
    :param features: List of features
    :param labels: List of labels
    :return: Batches of (Features, Labels)
    """
    assert len(features) == len(labels)
    outout_batches = []
    
    sample_size = len(features)
    for start_i in range(0, sample_size, batch_size):
        end_i = start_i + batch_size
        batch = [features[start_i:end_i], labels[start_i:end_i]]
        outout_batches.append(batch)
        
    return outout_batches

# %%
init = tf.global_variables_initializer()

batch_size = 128
epochs = 100
learn_rate = 0.01

train_batches = batches(batch_size, train_features, train_labels)

with tf.Session() as sess:
    sess.run(init)

    # Training cycle
    for epoch_i in range(epochs):

        # Loop over all batches
        for batch_features, batch_labels in train_batches:
            train_feed_dict = {
                features: batch_features,
                labels: batch_labels,
                learning_rate: learn_rate}
            sess.run(optimizer, feed_dict=train_feed_dict)

        # Print cost and validation accuracy of an epoch
        print_epoch_stats(epoch_i, sess, batch_features, batch_labels)

    # Calculate accuracy for test dataset
    test_accuracy = sess.run(
        accuracy,
        feed_dict={features: test_features, labels: test_labels})

print('Test Accuracy: {}'.format(test_accuracy))
# Out:
# Epoch: 0    - Cost: 6.62     Valid Accuracy: 0.269
# Epoch: 1    - Cost: 4.86     Valid Accuracy: 0.402
# Epoch: 2    - Cost: 3.88     Valid Accuracy: 0.497
# Epoch: 3    - Cost: 3.27     Valid Accuracy: 0.558
# Epoch: 4    - Cost: 2.84     Valid Accuracy: 0.607
# Epoch: 5    - Cost: 2.52     Valid Accuracy: 0.644
# Epoch: 6    - Cost: 2.28     Valid Accuracy: 0.669
# Epoch: 7    - Cost: 2.09     Valid Accuracy: 0.692
# Epoch: 8    - Cost: 1.94     Valid Accuracy: 0.709
# Epoch: 9    - Cost: 1.82     Valid Accuracy: 0.723
# Epoch: 10   - Cost: 1.72     Valid Accuracy: 0.732
# Epoch: 11   - Cost: 1.64     Valid Accuracy: 0.741
# Epoch: 12   - Cost: 1.56     Valid Accuracy: 0.748
# Epoch: 13   - Cost: 1.5      Valid Accuracy: 0.757
# Epoch: 14   - Cost: 1.44     Valid Accuracy: 0.768
# Epoch: 15   - Cost: 1.39     Valid Accuracy: 0.774
# Epoch: 16   - Cost: 1.34     Valid Accuracy: 0.781
# Epoch: 17   - Cost: 1.3      Valid Accuracy: 0.787
# Epoch: 18   - Cost: 1.26     Valid Accuracy: 0.793
# Epoch: 19   - Cost: 1.23     Valid Accuracy: 0.796
# Epoch: 20   - Cost: 1.2      Valid Accuracy: 0.8
# Epoch: 21   - Cost: 1.17     Valid Accuracy: 0.805
# Epoch: 22   - Cost: 1.14     Valid Accuracy: 0.809
# Epoch: 23   - Cost: 1.11     Valid Accuracy: 0.812
# Epoch: 24   - Cost: 1.09     Valid Accuracy: 0.813
# Epoch: 25   - Cost: 1.07     Valid Accuracy: 0.816
# Epoch: 26   - Cost: 1.04     Valid Accuracy: 0.819
# Epoch: 27   - Cost: 1.02     Valid Accuracy: 0.82
# Epoch: 28   - Cost: 1.01     Valid Accuracy: 0.823
# Epoch: 29   - Cost: 0.988    Valid Accuracy: 0.825
# Epoch: 30   - Cost: 0.972    Valid Accuracy: 0.828
# Epoch: 31   - Cost: 0.956    Valid Accuracy: 0.829
# Epoch: 32   - Cost: 0.941    Valid Accuracy: 0.831
# Epoch: 33   - Cost: 0.927    Valid Accuracy: 0.832
# Epoch: 34   - Cost: 0.914    Valid Accuracy: 0.833
# Epoch: 35   - Cost: 0.901    Valid Accuracy: 0.835
# Epoch: 36   - Cost: 0.889    Valid Accuracy: 0.837
# Epoch: 37   - Cost: 0.878    Valid Accuracy: 0.838
# Epoch: 38   - Cost: 0.867    Valid Accuracy: 0.84
# Epoch: 39   - Cost: 0.856    Valid Accuracy: 0.841
# Epoch: 40   - Cost: 0.846    Valid Accuracy: 0.844
# Epoch: 41   - Cost: 0.837    Valid Accuracy: 0.845
# Epoch: 42   - Cost: 0.827    Valid Accuracy: 0.846
# Epoch: 43   - Cost: 0.819    Valid Accuracy: 0.846
# Epoch: 44   - Cost: 0.81     Valid Accuracy: 0.848
# Epoch: 45   - Cost: 0.802    Valid Accuracy: 0.849
# Epoch: 46   - Cost: 0.794    Valid Accuracy: 0.85
# Epoch: 47   - Cost: 0.786    Valid Accuracy: 0.85
# Epoch: 48   - Cost: 0.779    Valid Accuracy: 0.851
# Epoch: 49   - Cost: 0.772    Valid Accuracy: 0.852
# Epoch: 50   - Cost: 0.765    Valid Accuracy: 0.853
# Epoch: 51   - Cost: 0.758    Valid Accuracy: 0.853
# Epoch: 52   - Cost: 0.752    Valid Accuracy: 0.854
# Epoch: 53   - Cost: 0.746    Valid Accuracy: 0.855
# Epoch: 54   - Cost: 0.74     Valid Accuracy: 0.856
# Epoch: 55   - Cost: 0.734    Valid Accuracy: 0.857
# Epoch: 56   - Cost: 0.729    Valid Accuracy: 0.858
# Epoch: 57   - Cost: 0.723    Valid Accuracy: 0.859
# Epoch: 58   - Cost: 0.718    Valid Accuracy: 0.859
# Epoch: 59   - Cost: 0.713    Valid Accuracy: 0.86
# Epoch: 60   - Cost: 0.708    Valid Accuracy: 0.861
# Epoch: 61   - Cost: 0.703    Valid Accuracy: 0.862
# Epoch: 62   - Cost: 0.699    Valid Accuracy: 0.863
# Epoch: 63   - Cost: 0.694    Valid Accuracy: 0.864
# Epoch: 64   - Cost: 0.69     Valid Accuracy: 0.864
# Epoch: 65   - Cost: 0.686    Valid Accuracy: 0.865
# Epoch: 66   - Cost: 0.682    Valid Accuracy: 0.865
# Epoch: 67   - Cost: 0.677    Valid Accuracy: 0.866
# Epoch: 68   - Cost: 0.674    Valid Accuracy: 0.866
# Epoch: 69   - Cost: 0.67     Valid Accuracy: 0.867
# Epoch: 70   - Cost: 0.666    Valid Accuracy: 0.867
# Epoch: 71   - Cost: 0.662    Valid Accuracy: 0.868
# Epoch: 72   - Cost: 0.659    Valid Accuracy: 0.868
# Epoch: 73   - Cost: 0.655    Valid Accuracy: 0.87
# Epoch: 74   - Cost: 0.652    Valid Accuracy: 0.87
# Epoch: 75   - Cost: 0.649    Valid Accuracy: 0.871
# Epoch: 76   - Cost: 0.645    Valid Accuracy: 0.871
# Epoch: 77   - Cost: 0.642    Valid Accuracy: 0.871
# Epoch: 78   - Cost: 0.639    Valid Accuracy: 0.871
# Epoch: 79   - Cost: 0.636    Valid Accuracy: 0.872
# Epoch: 80   - Cost: 0.633    Valid Accuracy: 0.872
# Epoch: 81   - Cost: 0.63     Valid Accuracy: 0.872
# Epoch: 82   - Cost: 0.627    Valid Accuracy: 0.872
# Epoch: 83   - Cost: 0.625    Valid Accuracy: 0.873
# Epoch: 84   - Cost: 0.622    Valid Accuracy: 0.874
# Epoch: 85   - Cost: 0.619    Valid Accuracy: 0.874
# Epoch: 86   - Cost: 0.616    Valid Accuracy: 0.874
# Epoch: 87   - Cost: 0.614    Valid Accuracy: 0.874
# Epoch: 88   - Cost: 0.611    Valid Accuracy: 0.875
# Epoch: 89   - Cost: 0.609    Valid Accuracy: 0.875
# Epoch: 90   - Cost: 0.606    Valid Accuracy: 0.875
# Epoch: 91   - Cost: 0.604    Valid Accuracy: 0.876
# Epoch: 92   - Cost: 0.602    Valid Accuracy: 0.876
# Epoch: 93   - Cost: 0.599    Valid Accuracy: 0.876
# Epoch: 94   - Cost: 0.597    Valid Accuracy: 0.877
# Epoch: 95   - Cost: 0.595    Valid Accuracy: 0.877
# Epoch: 96   - Cost: 0.593    Valid Accuracy: 0.877
# Epoch: 97   - Cost: 0.591    Valid Accuracy: 0.878
# Epoch: 98   - Cost: 0.588    Valid Accuracy: 0.878
# Epoch: 99   - Cost: 0.586    Valid Accuracy: 0.878
# Test Accuracy: 0.8747000098228455
